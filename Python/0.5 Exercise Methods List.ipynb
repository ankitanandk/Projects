# %%
1. Create a function that can create a copy of list n number of times. Let's say I need 3 times.
input=[1,2,3]
ouput=[1,2,3,1,2,3,1,2,3]

2. A function that would return the position of numbers above 10.
input=[1,2,3,13,21]
ouput=[3,4]

3. A function that would delete all numbers above 10.
input=[1,2,3,13,21]
ouput=[1,2,3]

4. A function that would reverse the list and keep non duplicates.
input=[1,2,2,3,13]
ouput=[13,3,2,1]

5. A function that would split the list midway. Let's say we have even items.
input=[1,2,4,13]
ouput=[1,2] [4,13]

6. A function that would split the list midway. Let's say we have odd items. First list shuld have n+1
input=[1,2,4,5,6]
ouput=[1,2,4] [5,6]

7. Append square to the same list.
input=[1,2,3]
ouput=[1,2,3,1,4,9]

8. Append square to the same list after every value.
input=[1,2,3]
ouput=[1,1,2,4,3,9]

9. Return the count of all int and floats. If the float value has more than 1 value after decimal, dont count
input=[1,2.2,3,"a","b",3.345]
ouput=3

10. Return the count of all floats which have an even value after decimal and digits after decimal is above 2
input=[1,2.2,3,"a","b",3.142,2.724]
ouput=2

11. Replace alternte value with missing value.
input=[1,2,3,4]
ouput=[1,None,3,None]

12. Add the last 2 list's sum to first list. Create a dynamic function that adds sum of all lists to parent list.
l1=[1,2,3]
l2=[10,10]
l3=[12,12]
ouput=[1,1,2,20,24]

13. Add the elements of list in sequence, first element of all list and so on, if any list is shorter then stop
l1=[1,2,3]
l2=[10,10]
l3=[12,12]
ouput=[23,24]

14. Insert the sum after every element.
input=[1,2,4]
ouput=[1,7,2,7,4,7]

15. Reverse all the nested lists 
input=[[1,2,4],[6,7,8]]
ouput=[[4,2,1],[8,7,6]]

16. Reverse all the nested lists 
input=[[1,2,4],[6,7,8]]
ouput=[[4,2,1],[8,7,6]]

17. Reverse all the nested lists; just keep even values
input=[[1,2,4],[6,7,8]]
ouput=[[4,2],[8,6]]

18. Delete the nested list which have more than 3 elements.
input=[[1,2,4],[6,7,8],[1,4,7,9,7]]
ouput=[[1,2,4],[6,7,8]]

19. Delete all enteries from parent if you find in child and store in new list
parent=[1,2,4,5,6,8]
child=[2,4,5]
output=[1,6,8]

20.  Delete all enteries from parent if you find in child and store in new list, if ONLY index and Value match
parent=[1,6,19,1]
child=[1,9,19]
output=[6,1]

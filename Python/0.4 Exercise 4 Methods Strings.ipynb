# %%
1. Delete all the lowercase alphabets from the string.
input="amiT123"
output="T123"

2. Delete all the  alphabets from the string.
input="amit123"
output="123"

3. Separate the list alphabets into 3 different lists. Lowecracse, upcase and numbers
input="amiT123"
output=[ami][T][123]

4. Count all instances of a in upper and lowercase.
input="amiTAbh"
output=2

5. Sum the index of alphabet "a", create a user defined function
input="miatabh"
output=6

7. Count Number of words that are NOT repeating in string, the words should not be part of bigger word
input="my name is misery and luck"
output=5

8. Return the count if any of the word is part of any other word.Here is ,and are part of other words. 
input="my andy boy is misery and luck"
output=2

9. Return the count of unique alphabets
input="the new car "
output=8

10. Create a counter that counts all words in a string and word.Output is list with count and total count in last.
input="my name is amitabh"
output=[2,4,2,7,4]

10. Delete all vowels from a string.
input="my name is amit"
output="my nm s mt"

11. Delete from parent if that char is available in child. Delete chars, not words.
parent="my name is amit"
child="mi"
output='y nae s at'

12. Create a dictionary with word and its count
input="my name is"
output={'my':2,'name':4,'is':2}

13. Give me the central word in a sentence.Let's say words are odd in count.
input="my name is amit kumar"
output="is"

14. Give me the central word in a sentence.Let's say words are even in count.
input="my name amit kumar"
output="name amit"

15. Extract the word that has no count of alphabet "a"
input="my name is ahaana khan"
output="my is"

16. Extract the word that has the highest count of alphabet "a"
input="my name is ahaana khan"
output="ahaana"

17. Extract the word that has sum of highest alphabet index, lets say a=1, b=2 so score of "ab" is 3.
input="my fav past time is jazz"
output="jazz"

18. Extract the word that has sum of least alphabet index, lets say a=1, b=2 so score of "ab" is 3.
input="aaj my fav past time is jazz"
output="aaj"

19. Write a program/function that would give count of all spaces. Leading, trailing and intermediate.
input=" u guys asked for this exercise  "
output=[leading=1,intermediate=5, trailing=2]

20. Write a code that would substitute spaces with #

input='this is last qn'
output='this#is#the#last#qn'
